# %% [markdown]
# # 🚀 Introduction to AI Agents
#
# This notebook explores:
#
# 1. What an **AI Agent** is
# 2. Core **Building‑Blocks**
# 3. **Frameworks**
# 4. **Monitoring & Evaluation**
# 5. **Use‑cases & Patterns**
# 6. 🧠 **Human‑in‑the‑Loop**

# %% [markdown]
# ## 1. What is an AI Agent?
#
# ![ai-agents-en-1-min.jpg](data:image/jpeg;base64,...)
#
# An **AI agent** is a system that autonomously performs tasks by:
#
# - **Reasoning** with an LLM backbone
# - **Planning** step‑by‑step actions
# - Calling **Tools** (APIs, web scraping, DBs, etc.)
# - Maintaining **Memory** across interactions
# - Following **Guardrails** for safe & ethical behavior

# %% [markdown]
# ## 2. Building Blocks of AI Agents
#
# ### 🧠 2.1 LLM as Backbone
# Modern agents rely on large language models (e.g., GPT‑4, Gemini) for natural language understanding and generation.
#
# ![Image-1-100-2.jpg](data:image/jpeg;base64,...)
#
# ### 2.2 Memory
# - **Short‑term**: Context of current session
# - **Long‑term**: Persistent memory across sessions
#
#
# ![short-vs-long.png](data:image/png;base64,...)
#
# ### 2.3 Tools
# Agents integrate with:
# - Web search/scraping
# - APIs & databases
# - Code execution engines
# - And more…
# ![image.png](data:image/png;base64,...)
# ### 2.4 Guardrails
# To ensure ethical and safe outputs, guardrails validate inputs/outputs and restrict behavior.
#
# ![1_Cw1Rpdh_PfMw4fceggFeKQ.webp](data:image/webp;base64,...)

# %% [markdown]
# ## 3. Frameworks
#
# Several popular frameworks help you build agents more easily:
# ![7-agentic-ai-frameworks.webp](data:image/webp;base64,...)
#
# ### LangGraph
# Graph‑based workflows with clear control‑flow nodes.
#
# ### OpenAI Agents SDK
# Plug‑and‑play multi‑step agents, great if you’re already using OpenAI tools.
#
# ### Pydantic AI
# Schema‑driven agents with type safety and structured I/O.
#
# ### Hugging Face SmolAgents
# Minimalist, lightweight — you write simple Python loops.
#
# ### CrewAI
# Role‑based multi‑agent teamwork. Great for structured collaboration.
#
# ### AutoGen
# Flexible multi‑agent conversation framework, supports complex orchestration.

# %% [markdown]
# ## 4. Monitoring & Evaluation
#
# ### Monitoring
# - **Langfuse** tracks LLM calls, tool usage, decisions and logs.
# - **Logfire** (part of Pydantic AI) integrates with Langfuse for logging agent events.
#
# ### Evaluation
# Use offline metrics and live tracing (Langfuse) to detect failures, measure cost, assess compliance.

# %% [markdown]
# ## 5. Use‑Cases of AI Agents
#
# | Agent Type                           | Description |
# |------------------------------------|-------------|
# | **Voice Agent**                    | Conversational assistant for audio interfaces |
# | **Call Agent**                     | Automates voice calls (e.g., customer service) |
# | **Web‑Search Agent**               | Queries and summarizes web content |
# | **Complex Workflow Automation**    | Orchestrates multi‑step tasks |
# | **SQL Agent**                      | Handles DB queries & manipulation |
# | **Code‑Writing Agent**             | Generates code snippets or full modules |
# | **Team as Agent**                  | Multi‑agent setups with role specialization |
# | **Content‑Generation Agent**       | Produces text, images, etc. |
# | **Multi‑Agent System**            | Agent networks coordinating to solve complex tasks |
# | **Human‑in‑the‑Loop**             | Human oversight mid‑process for interventions/validation |

# %% [markdown]
# ## 6. Example Flow: Voice Agent
# ![voice-ai-dark_1.png](data:image/png;base64,...)
#
# 1. **User speaks** → STT → text
# 2. **Agent plans** steps (intent detection, tool choice)
# 3. Calls tools (calendar API, web search, TTS)
# 4. **Returns spoken response**
# 5. Logs each step in **Langfuse**
# 6. Evaluation: assess STT accuracy, latency, completion

# %% [markdown]
# ## 7. No Code AI Agents
#
# ![unnamed.png](data:image/png;base64,...)

# %% [markdown]
# ## 8. Building and Deploying an Agent
#
# ![ai-img-agent_design_flow-da642f65925824996cf65ab4b97c5192.png](data:image/png;base64,...)

# %% [markdown]
# ## 9. Putting It All Together
#
# This notebook introduces foundational concepts of AI agents, their building blocks, ecosystem frameworks, monitoring practices, evaluation strategies, and diverse real‑world use cases. Students will get both theoretical grounding and a roadmap to prototype their own agents.
